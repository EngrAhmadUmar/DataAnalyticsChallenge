# %% [markdown]
# <img src="Logo.png" width=250 height=250 />

# %%
#Group 2
# Group members:-
# Ahmad Ahmad
# Shiela Bwiza
# Jose Cumba
# Nancy Umutoni 
# Pacis Ishimwe

# %%
# Here we are trying to import the libraries we need.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Trying to upload the database.

#My first dataset contains Revenue data, about the amount of revenue 
#recieved from each state in Nigeria, in the past three years.
data = pd.read_csv("NigeriaRevenue.csv")
#The second dataset contains how the revenue generated in the country 
#is beign allocated to different sectors in the country
data1= pd.read_csv("NigeriaRevenueAllocation.csv")
#The dataset i am importing below is a sentiment dataset 
#which contains a lot of tweets of nigerian citizens
data2 = pd.read_csv("NigeriaStandardHeadlinesCleansed.csv")

# %%
# Trying to view the top three elements in my first database(i.e NigeriaRevenue.csv)
data.head(3)
# Out:
#   Nigerian States      FY 2018/19      FY 2019/20      FY 2020/21  \
# 0            Abia  $6,309,422,078  $6,744,720,378  $5,760,563,498
# 1         Adamawa  $4,022,156,734  $4,457,455,034  $3,473,298,154
# 2       Akwa Ibom  $4,985,857,461  $5,421,155,761  $4,436,998,881
#
#        FY 2021/22
# 0  $7,302,313,445
# 1  $8,672,583,532
# 2  $7,503,515,170

# %%
#As we can see above, we can view the amount generated in $USD in the past 3 years by Nigerian
#states and how much they contribute to the economy.

# %%
# Trying to view the top three elements in my second database(i.e NigeriaRevenueAllocation.csv)
data1.head(3)
# Out:
#         Years           Education              Health             Defense  \
# 0  FY 2018/19  $63,093,409,323.00  $72,093,409,323.00  $33,093,409,323.00
# 1  FY 2019/20  $62,093,409,323.00  $79,093,409,323.00  $32,093,409,323.00
# 2  FY 2020/21  $62,093,409,323.00  $69,593,409,323.00  $33,093,409,323.00
#
#           Information             Housing Works & Infastructure  \
# 0  $23,093,409,323.00  $13,093,409,323.00    $13,093,409,323.00
# 1  $23,093,409,323.00  $15,093,409,323.00    $13,093,409,323.00
# 2  $23,093,409,323.00  $13,093,409,323.00    $13,093,409,323.00
#
#              Justice    Foreign Affairs Science & Technology  \
# 0  $7,093,409,323.00  $3,093,409,323.00   $20,093,409,323.00
# 1  $7,093,409,323.00  $3,093,409,323.00   $23,093,409,323.00
# 2  $7,093,409,323.00  $3,093,409,323.00   $20,093,409,323.00
#
#                 Sport         Agriculture              Power  \
# 0  $12,093,409,323.00  $10,093,409,323.00  $2,003,958,020.00
# ...

# %%
#As we can see above, we can view how the generated revenue is being spread across
#different sectors in the country, such as health, education, defence, e.t.c

# %%
# Trying to view the top three elements in my last database(i.e NigeriaStandardHeadlinesCleansed.csv")
data2.head(10)
# Out:
#         Date                                           Headline     Category
# 0  1/14/2018  I cant believe what has happened to our health...  Poor Health
# 1  1/14/2018          Our health system has been poor this year  Poor Health
# 2  1/15/2018             engagement might pay off for mnangagwa       Normal
# 3  1/15/2018        man granted peace against disrespectful son       Normal
# 4  1/15/2018                             Abysymal Health system  Poor Health
# 5  1/21/2018                               Hospitals are decent  Good Health
# 6  1/21/2018  khupe mudzuri and chamisa who will take the md...    Political
# 7  1/21/2018  expats offer free heart testing at chinhoyi ho...       Social
# 8  1/21/2018               zec ready for elections says ziyambi    Political
# 9  1/21/2018              white farmer in bid  to get back farm    Political

# %%
#Taking a look at our sentimental database, as we can see above this database contains
#Tweets of nigerian citizens.
#As we can see from the preview, the tweets are divided into tweets that speak 
#good or bad about the health system, then some tweets which are normal

# %%
#Here we are trying to view the number of rows and colums in our first dataset, 
#So we can know what we are working with
data.shape
# Out:
# (39, 5)

# %%
#Here we are trying to view the number of rows and colums in our second dataset, 
#So we can know what we are working with.
data1.shape
# Out:
# (4, 16)

# %%
#Here we are trying to view the number of rows and colums in our sentiment dataset, 
#So we can know what we are working with.
data2.shape
# Out:
# (710, 3)

# %%
#Webscrapping
#Here we are webscrapping with the aim for finding information that maybe beneficial to 
#Us on bbc.com.
#We chose bbc because it is one of the most reliable news sources in the worlds.
import requests
page = requests.get('https://www.bbc.com/')
contents = page.content
print(contents)
# Out:
# b'    <!DOCTYPE html>\n<html class="b-header--black--white b-pw-1280 b-reith-sans-font">\n\n    <head>\n        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n        <meta name="description" content="Breaking news, sport, TV, radio and a whole lot more.\n        The BBC informs, educates and entertains - wherever you are, whatever your age.">\n        <meta name="keywords" content="BBC, bbc.co.uk, bbc.com, Search, British Broadcasting Corporation, BBC iPlayer, BBCi">\n        <title>BBC - Homepage</title>\n\n        <script>\n            window.orb_fig_blocking = true;\n            window.bbcredirection = {geo: true};\n        </script>\n\n        <!-- WWHPv: 20210222-0913-13d09a2a9c8c32b50626600535f23f7853b7385f -->\n        <!-- Webapp: WWHP international homepage -->\n        <meta property="fb:page_id" content="228735667216" />\n        <meta property="fb:admins" content="297814326937641" />\n        <meta property="fb:app_id" content="187214818032936" />\n
# ...

# %%
#Importing the csv file.
plt.style.use('bmh')
# df = pd.read_csv("NigeriaRevenue.csv")
df = pd.read_csv('NigeriaRevenue.csv', sep=r'\s*,\s*',
                           header=0, encoding='ascii', engine='python')

# %%
#Plotting the graphs to show how much revenue generated by each Nigeria state 2018

#Increasing the size of my graph
fig= plt.figure(figsize=(20,9))

# Setting the values of my x and y axis
x = df['Nigerian States']
y = df['FY 2018/19']

#Plotting the graph with 1 unit to represent $400000 on the x-axis
plt.bar(x,y)
plt.show()

# %%
#Plotting the graphs to show how much revenue generated by each Nigeria state in 2019

#Increasing the size of my graph
fig= plt.figure(figsize=(20,9))

# Setting the values of my x and y axis
x = df['Nigerian States']
y = df['FY 2019/20']

#Plotting the graph with 1 unit to represent $400000 on the x-axis
plt.bar(x,y)
plt.show()

# %%
#Plotting the graphs to show how much revenue generated by each Nigeria state 2020

#Increasing the size of my graph
fig= plt.figure(figsize=(20,9))

# Setting the values of my x and y axis
x = df['Nigerian States']
y = df['FY 2020/21']

#Plotting the graph with 1 unit to represent $400000 on the x-axis
plt.bar(x,y)
plt.show()

# %%
#Plotting the graphs to show how much revenue generated by each Nigeria state 2021

#Increasing the size of my graph
fig= plt.figure(figsize=(20,9))

# Setting the values of my x and y axis
x = df['Nigerian States']
y = df['FY 2019/20']

#Plotting the graph with 1 unit to represent $400000 on the x-axis
plt.bar(x,y)
plt.show()

# %%
#Below i shall be plotting a graph to show the total revenue generated by Niger
# Across the years

# %% [markdown]
# <img src="TotalRevenue.PNG" width=500 height=400 />

# %%
#Now we shall peak our dataset, that hows how Nigeria uses this revenue generated
data1.head(3)
# Out:
#         Years        Education           Health          Defense  \
# 0  FY 2018/19  $63,093,409,323  $72,093,409,323  $33,093,409,323
# 1  FY 2019/20  $62,093,409,323  $79,093,409,323  $32,093,409,323
# 2  FY 2020/21  $62,093,409,323  $69,593,409,323  $33,093,409,323
#
#        Information          Housing Works & Infastructure         Justice  \
# 0  $23,093,409,323  $13,093,409,323       $13,093,409,323  $7,093,409,323
# 1  $23,093,409,323  $15,093,409,323       $13,093,409,323  $7,093,409,323
# 2  $23,093,409,323  $13,093,409,323       $13,093,409,323  $7,093,409,323
#
#   Foreign Affairs Science & Technology            Sport      Agriculture  \
# 0  $3,093,409,323      $20,093,409,323  $12,093,409,323  $10,093,409,323
# 1  $3,093,409,323      $23,093,409,323  $12,093,409,323  $15,093,409,323
# 2  $3,093,409,323      $20,093,409,323  $12,093,409,323  $10,093,409,323
#
#             Power  Transportation             Total  Unnamed: 15
# ...

# %%
#So now below, we shall be looking at how the revenue has 
#Affected the amount of money being put into the health sector by plotting graph showing 
#how much the health sector recieves
#Because we are looking to see how health has improved since the pandemic.

# %% [markdown]
# <img src="InvestmentInHealth.PNG" width=500 height=400 />

# %%
#As we can see above, After the series of complaints by the citizens of nigeria, 
#the government decided to increase the import tax, by 7%, which bolstered the government revenue generation, 
#which inturn gave the government enough financial freedom to invest more in health, 
#which made the health services pick up and be far better than the previous year.
